# %% [markdown]
# # Computer Vision Assignment 1

# %%
# https://www.dataquest.io/blog/jupyter-notebook-tips-tricks-shortcuts/
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage import data,filters
import numpy as np

# %% [markdown]
# ## Question 1

# %%
a = plt.imread("greenscreen.jpg")
cat =plt.imread("cat.jpg")
# Get a part of cat that is the same size as the greenscreen
cat = cat[130:505,200:700,:]
b = np.zeros_like(a)
empty = np.zeros_like(a)
r, g, b = (2, 1, 0)
# Get different channels of original image
red = a[:, :, r]
green = a[:, :, g]
blue = a[:, :, b]
# Get all pixels where green is in the threshold and also
# where greens are smaller than either of the other colours
mask = (greens < 179) | (red > green) | (blue > green)
# Get Inverse mask
un_mask = np.invert(mask)
# Empty image
green = np.zeros_like(a, np.uint8)
green[mask] = a[mask]
green[un_mask] = cat[un_mask]

# %%
plt.imshow(green)

# %% [markdown]
# ## Question 2

# %%
import cv2

# Load an color image in grayscale
img = cv2.imread('cat.jpg',0)
cv2.imshow('image',img)
